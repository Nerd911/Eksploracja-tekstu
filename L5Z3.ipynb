# %%
import numpy as np
from collections import defaultdict as dd
from typing import List, Dict, Set
import nltk
from math import log, ceil
import time
import sys
import pandas as pd

# %%
import pickle
with open("Dane/wiki_list", "rb") as ifile:
    wiki_list = pickle.load(ifile)

# %%
def to_lemma_mapping():
    all_lemmas = dd(list)
    for line in open('Dane/polimorfologik-2.1.txt', encoding='utf-8'):
        L = line.split(';')[:2]
        all_lemmas[L[1].lower()].append(L[0].lower())
    return all_lemmas

# %%
lemmas = to_lemma_mapping()

# %%
with open("Dane/polish.stopwords.txt", "r") as ifile:
    stopwords = [line[:-1] for line in ifile]

# %%
df = pd.read_csv("Dane/nkjp+wiki-forms-all-100-cbow-hs.txt", sep = " ", skiprows=1, names=np.arange(101))

# %%
df = df.transpose()

# %%
df.columns = df.iloc[0]

# %%
df = df.drop(df.index[0])

# %%
df = df.astype(float)

# %%
df
# Out:
# 0           w         i        na         z       się       nie        do  \
# 1   -0.623933 -0.927808  0.149684  0.727299 -0.777044 -1.945414 -0.868247
# 2    2.184556  0.920390  3.621207  2.601258  6.364845  5.001998  2.539189
# 3   -2.251491 -1.175119 -3.882869 -3.080432  0.160861  0.304228 -3.158081
# 4   -1.645580 -1.256960 -2.175517 -3.438949  1.954626  1.160726 -0.869770
# 5   -0.536714 -1.419652 -0.109260  0.080732  1.527357  1.649076 -0.214892
# ..        ...       ...       ...       ...       ...       ...       ...
# 96   2.281199  0.297114  3.751207  0.579685  3.807668  1.476270  0.433092
# 97  -0.564484 -0.052366 -0.191766  0.820845 -1.219506  0.811136  0.713117
# 98   0.368470  0.141112  0.782745  2.188098  3.017649  1.491073  0.331562
# 99  -0.392994 -0.616809  0.411928 -1.691921 -0.915923  1.239788  0.578034
# 100  0.772953  0.488571 -0.551159 -0.215950 -0.628436  2.457059 -0.205353
#
# 0          to        że      jest  ...     Zloze  vanetris  simeticon  \
# 1    0.721761 -4.128553  0.316921  ...  0.194326  0.078611   0.057075
# 2    1.916624  5.105642  2.905746  ... -0.361449  0.445908   0.136646
# 3    0.537992 -1.619554 -0.851985  ... -0.033670 -0.411248  -0.191859
# 4    0.418699 -0.684059  0.376432  ...  0.391813  0.050264   0.303088
# 5    0.408665  0.044076  4.313750  ... -0.147650 -0.073459  -0.241235
# ..        ...       ...       ...  ...       ...       ...        ...
# 96   1.412012  3.234749 -2.722966  ...  0.026496 -0.004306   0.606828
# 97  -0.803451  0.102479  0.295406  ... -0.175712 -0.420796   0.025902
# 98   0.850248  1.124183  5.378809  ... -0.128617 -0.264147  -0.116367
# 99   2.401441  1.549452 -1.863822  ...  0.105183  0.219090  -0.259805
# 100  0.394166  4.641745 -3.596552  ... -0.312077 -0.183935   0.280958
#
# 0    zespalaniem     Ijiri  swisscharts      Uyar  magistersk  \
# 1       0.036449 -0.225772    -0.294211  0.351418    0.087362
# 2      -0.259968 -0.118344     0.079538  0.723339    0.200133
# 3      -0.422267 -0.007936    -0.305253 -0.179755    0.080401
# 4      -0.066533  0.125705    -0.039943 -0.091873   -0.324414
# 5      -0.030672  0.053438     0.236704  0.009023    0.365923
# ..           ...       ...          ...       ...         ...
# 96      0.385571 -0.292690     0.469974 -0.023422   -0.416877
# 97     -0.178444 -0.096237    -0.461366 -0.507556   -0.237156
# 98     -0.320293  0.031340     0.030483 -0.231535   -0.326573
# 99     -0.468503 -0.032151    -0.514650 -0.095760    0.184661
# 100    -0.243675 -0.092139     0.474675  0.364828   -0.078393
#
# 0    telepracownikom  Lancieux
# 1          -0.046845  0.128815
# 2          -0.618282  0.190157
# 3           0.185796  0.097010
# 4           0.200701  0.070601
# 5          -0.046027 -0.202354
# ..               ...       ...
# 96         -0.417928 -0.167236
# 97         -0.155177 -0.377874
# 98          0.173437 -0.212349
# 99         -0.019706  0.063062
# 100         0.259773 -0.110105
#
# [100 rows x 2123132 columns]

# %%
def preprocess_article(wiki_list, stopwords):
    article_vectors = []
    for title, article in wiki_list:
        article_vector = np.zeros(100)
        for line in article[:2]:
            for w in line:
                w = w.lower()
                if not w.isalpha():
                    continue
                if w in stopwords:
                    continue
                if w not in lemmas:
                    lemmas[w] = [w]
                for el in lemmas[w]:
                    if el not in df.columns:
                        continue
                    article_vector += df[el].to_numpy()
        article_vectors.append(article_vector)
    return article_vectors

# %%
preprocess_article(wiki_list, stopwords)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-3de98f15b096> in <module>
# ----> 1 preprocess_article(wiki_list, stopwords)
#
# <ipython-input-24-f81fcd5a3e74> in preprocess_article(wiki_list, stopwords)
#      15                     if el not in df.columns:
#      16                         continue
# ---> 17                     article_vector += df[el].to_numpy()
#      18         article_vectors.append(article_vector)
#      19     return article_vectors
#
# TypeError: ufunc 'add' output (typecode 'O') could not be coerced to provided output parameter (typecode 'd') according to the casting rule ''same_kind''

# %%
vectors

# %%
"test"
