# %%
import numpy as np
from collections import defaultdict as dd
from typing import List, Dict, Set
import nltk
from tqdm import tqdm_notebook, tnrange
import pickle
from termcolor import colored

# %%
def load_word_set():
    all_lemmas = set()
    for line in open('Dane/polimorfologik-2.1.txt', encoding='utf-8'):
        L = line.split(';')[1].lower()
        all_lemmas.add(L)
    return all_lemmas

# %%
def fix_ngram(ngram, word_set):
    words = nltk.word_tokenize(ngram)
    ok = True
    for word in words:
        if word not in word_set:
            ok = False
    if ok:
        return [ngram]
    words_joined = "".join(words)
    result = []
    if words_joined in word_set:
        result.append(words_joined)
    for i in range(1, len(words_joined)):
        word1, word2 = words_joined[:i], words_joined[i:]
        if word1 in word_set and word2 in word_set:
            result.append(" ".join([word1, word2]))
    if len(result) == 0:
        return [ngram]
    return result

# %%
word_set = load_word_set()

# %%
with open("Dane/test.txt", "r") as ifile:
    for line in ifile:
        print(f"{line} {fix_ngram(line, word_set)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-63f0d1d6b2fc> in <module>
# ----> 1 with open("Dane/test.txt", "r") as ifile:
#       2     for line in ifile:
#       3         print(f"{line} {fix_ngram(line, word_set)}")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dane/test.txt'

# %%
result = []

# %%
with open("Dane/2grams", "r") as ifile:
    for line in ifile:
        line_split = nltk.word_tokenize(line)
        line = " ".join(line_split[1:])
        fixed = fix_ngram(line, word_set)
        if fixed != [line]:
            result.append((line, fixed))
            print(line)
            print(fixed)
# Out:
# bym nie
# ['by mnie']
# sa w
# ['saw']
# tp sa
# ['t psa']
# sa i
# ['s ai']
# gdybym nie
# ['gdyby mnie']
# psp w
# ['ps pw']
# c z
# ['cz']
# żebym nie
# ['żeby mnie']
# polska sa
# ['polsk asa']
# c i
# ['ci']
# jak bym
# ['jakby m']
# i koniec .
# ['ikonie c.']
# l i
# ['li']
# w czoraj
# ['wczoraj', 'wc zoraj']
# sa oraz
# ['sao raz']
# do iv
# ['doi v']
# sa z
# ['s az']
# of a
# ['o fa']
# o l
# ['ol']
# tu sa
# ['t usa']
# i iv
# ['ii v']
# kmp w
# ['k mpw', 'km pw']
# żebyś nie
# ['żeby śnie']
# ś w
# ['św']
# co bym
# ['coby m']
# byś nie
# ['by śnie']
# l o
# ['lo']
# to moze
# ['tomo ze']
# sa jest
# ['saje st']
# for the
# ['fort he']
# sa nie
# ['sanie', 's anie', 'san ie', 'sani e']
# sa na
# ['sana', 'san a']
# j a
# ['ja']
# l a
# ['la']
# t y
# ['ty']
# w c .
# ['w c.']
# nie mozna
# ['niemo zna']
# d ziś
# ['dziś']
# a c
# ['ac']
# l na
# ['ln a']
# bym w
# ['by mw']
# nie moze
# ['niemo ze']
# j uż
# ['już']
# sam bym
# ['samby m']
# l e
# ['le']
# a l
# ['al']
# na dworzec .
# ['nadworze c.']
# owu mienia
# ['ow umienia']
# p onad
# ['ponad', 'po nad', 'pon ad']
# bym z
# ['by mz']
# to nic .
# ['toni c.']
# j e
# ['je']
# moze sie
# ['moz esie']
# moze to
# ['mo zeto', 'moz eto']
# pkp sa
# ['pk psa', 'pkps a']
# to sa
# ['t osa', 'tos a']
# a source
# ['aso urce']
# jakbym nie
# ['jakby mnie']
# p iłkarze
# ['piłkarze', 'pił karze', 'piłkarz e']
# p rzed
# ['przed', 'prze d']
# bank sa
# ['banksa', 'banks a']
# de mello
# ['dem ello']
# prawie nic .
# ['prawieni c.']
# vi i
# ['v ii']
# at the
# ['att he']
# abym nie
# ['aby mnie']
# gok w
# ['go kw']
# i noc .
# ['ino c.']
# l nie
# ['lnie', 'ln ie']
# moze nie
# ['m ozenie', 'mo zenie']
# warta sa
# ['wart asa']
# sa za
# ['s aza']
# i the
# ['it he']
# l co
# ['lc o']
# gdybyś nie
# ['gdyby śnie']
# c oraz
# ['coraz', 'co raz', 'cor az', 'cora z']
# i c .
# ['i c.']
# c o
# ['co']
# ś nie
# ['śnie', 'śni e']
# nns a
# ['n nsa']
# w owu
# ['wow u']
# o nic .
# ['oni c.']
# pirate bay
# ['pirat ebay']
# o ś
# ['oś']
# nota bene
# ['notabene']
# ma nic .
# ['mani c.']
# m ieszkańcy
# ['mieszkańcy']
# p olicjanci
# ['policjanci']
# stopni c .
# ['stopni c.']
# sa do
# ['s ado', 'sad o']
# d zisiaj
# ['dzisiaj']
# j eszcze
# ['jeszcze']
# na prawde
# ['napraw de']
# de lege
# ['deleg e']
# zso nr
# ['zs onr']
# bede sie
# ['be desie', 'bed esie']
# j ak
# ['jak', 'ja k']
# iv w
# ['i vw']
# tc z
# ['t cz']
# e j
# ['ej']
# old boys
# ['oldboy s']
# e l
# ['el']
# gdybym w
# ['gdyby mw']
# europa sa
# ['euro pasa', 'europ asa']
# kazdy ma
# ['ka zdyma']
# p odczas
# ['podczas', 'pod czas']
# sa o
# ['sao']
# abyś nie
# ['aby śnie']
# bp sa
# ['b psa', 'bps a']
# m ppł
# ['mp pł']
# ppe w
# ['pp ew']
# bym ich
# ['by mich']
# o c
# ['oc']
# a ż
# ['aż']
# dzu z
# ['d zuz', 'dz uz']
# tu poru
# ['t uporu']
# j utro
# ['jutro', 'jut ro', 'jutr o']
# vi w
# ['v iw']
# że bym
# ['żeby m']
# bo bym
# ['boby m']
# i wogole
# ['iwo gole']
# we l
# ['wel', 'w el']
# f i
# ['fi']
# żebym z
# ['żeby mz']
# a j
# ['aj']
# w the
# ['wt he']
# na rue
# ['nar ue']
# dzieki za
# ['dziek iza']
# żebym w
# ['żeby mw']
# helion sa
# ['he lionsa']
# kp psp
# ['kpp sp']
# ze ktos
# ['zek tos']
# j eśli
# ['jeśli']
# sa ma
# ['sama', 'sam a']
# l od
# ['lod', 'lo d']
# j est
# ['jest', 'je st']
# mock i
# ['mocki', 'moc ki']
# grupa c
# ['grup ac']
# gdybyś miał
# ['gdyby śmiał']
# z amiką
# ['za miką']
# mock nie
# ['m ocknie']
# sdpl i
# ['sdp li']
# tvp sa
# ['tv psa']
# i wogóle
# ['iw ogóle']
# reiki i
# ['rei kii']
# ż e
# ['że']
# l po
# ['lp o']
# l z
# ['lz']
# na swiecie
# ['nas wiecie']
# sa od
# ['sao d']
# usd na
# ['us dna']
# c zy
# ['czy']
# f o
# ['fo']
# w y
# ['wy']
# k iedy
# ['kiedy', 'ki edy']
# sędzia sa
# ['sędzi asa']
# w gp
# ['wg p']
# l n
# ['ln']
# are the
# ['aret he']
# ex post
# ['expo st']
# to napewno
# ['tona pewno']
# bylam na
# ['by lamna']
# vii i
# ['v iii']
# ale jakos
# ['aleja kos']
# byc z
# ['bycz', 'by cz']
# jakbyś nie
# ['jakby śnie']
# nie mhm
# ['niem hm']
# sa po
# ['sapo', 's apo', 'sap o']
# w ładze
# ['władze', 'wł adze', 'wład ze', 'władz e']
# z kmp
# ['zk mp']
# i sa
# ['is a']
# by the
# ['byt he']
# h o
# ['ho']
# j w
# ['jw']
# sdpl nie
# ['sdp lnie']
# s ąd
# ['sąd', 'są d']
# bym im
# ['by mim']
# pbk sa
# ['pbks a']
# a nic .
# ['ani c.']
# g dy
# ['gdy']
# anna sztym
# ['annasz tym']
# bym o
# ['by mo']
# t ylko
# ['tylko']
# grupie c
# ['gr upiec']
# h i
# ['hi']
# jakbyś miał
# ['jakby śmiał']
# c a
# ['ca']
# george ’ a busha
# ['george’a busha']
# na vii
# ['n avii']
# c hoć
# ['choć']
# troche sie
# ['troch esie']
# witamina c
# ['witamin ac']
# r adni
# ['radni', 'rad ni', 'radn i']
# group i
# ['gro upi']
# l ale
# ['lale', 'la le', 'lal e']
# php i
# ['ph pi']
# gops w
# ['gop sw']
# s ą
# ['są']
# t rzy
# ['trzy']
# u czniowie
# ['uczniowie', 'uczn iowie', 'uczniowi e']
# vi lo
# ['v ilo']
# w zb
# ['wz b']
# abym w
# ['aby mw']
# sa bardzo
# ['saba rdzo']
# i napewno
# ['ina pewno']
# niż nic .
# ['niżni c.']
# p olicja
# ['policja', 'po licja', 'polic ja']
# u c
# ['uc']
# zso w
# ['zs ow']
# c do
# ['cd o']
# j ą
# ['ją']
# m imo
# ['mimo', 'mi mo', 'mim o']
# u l
# ['ul']
# w cu
# ['wc u']
# z ałganowem
# ['załga nowem']
# bo sa
# ['bosa', 'b osa', 'bos a']
# o ppe
# ['op pe']
# sa przez
# ['sap rzez']
# bym i
# ['by mi']
# b ardzo
# ['bardzo', 'ba rdzo']
# reiki nie
# ['rei kinie']
# pko sa
# ['p kosa', 'pk osa']
# strong man
# ['strongman']
# united i
# ['unit edi']
# w fap
# ['wf ap']
# c na
# ['cna']
# ktore nie
# ['kto renie']
# nie wiedząc .
# ['niewiedzą c.']
# p rokuratura
# ['prokuratura', 'prokura tura', 'prokurat ura', 'prokuratur a']
# stu sa
# ['st usa']
# z arząd
# ['zarząd', 'za rząd', 'zarzą d']
# ktos jest
# ['kto sjest']
# w aninie
# ['wa ninie', 'wan inie', 'wani nie']
# z espół
# ['zespół', 'ze spół']
# no moze
# ['nomo ze']
# owu nie
# ['o wunie', 'ow unie']
# to moj
# ['tom oj']
# bylo by
# ['by loby']
# kgw w
# ['kg ww']
# ptu sa
# ['pt usa']
# p rzy
# ['przy']
# w szystko
# ['wszystko']
# de gaulle ’ a
# ['de gaulle’a']
# ktos sie
# ['kto ssie']
# sa dla
# ['sad la']
# sosw w
# ['sos ww']
# wogole nie
# ['w ogolenie']
# w abu
# ['wabu', 'wa bu', 'wab u']
# w c
# ['wc']
# ale napewno
# ['alena pewno']
# apple nie
# ['ap plenie']
# h a
# ['ha']
# io w
# ['iow', 'i ow']
# iv cr
# ['i vcr']
# m y
# ['my']
# nie mówie
# ['niemów ie']
# to mozna
# ['tomo zna']
# with a
# ['wit ha']
# jakie sa
# ['ja kiesa']
# sa może
# ['samo że']
# witaminy c .
# ['witaminy c.']
# że nic .
# ['żeni c.']
# a takze
# ['atak ze']
# banku sa
# ['ban kusa', 'bank usa']
# c e
# ['ce']
# gmo do
# ['g modo', 'gm odo']
# isc na
# ['is cna']
# nowara z
# ['nowa raz']
# patrzec na
# ['patrze cna']
# ucze sie
# ['u czesie', 'ucz esie']
# us army
# ['usar my']
# na nia
# ['n ania']
# pln i
# ['pl ni']
# pz nr
# ['pzn r']
# sa bożena
# ['sabo żena']
# stopni c
# ['stopnic', 's topnic', 'stop nic']
# w aig
# ['wa ig']
# ja vohl
# ['javo hl']
# l marek
# ['lm arek']
# moze w
# ['mo zew', 'moz ew']
# pack 2
# ['pac k2']
# w php
# ['wp hp']
# żebyś miał
# ['żeby śmiał']
# kaja mikoszewska
# ['kajami koszewska']
# l u
# ['lu']
# ogole nie
# ['ogolenie', 'o golenie', 'ogoleni e']
# jakbym w
# ['jakby mw']
# nie chca
# ['niech ca']
# p ierwsze
# ['pierwsze']
# tfi nie
# ['t finie']
# tu bym
# ['tuby m']
# union i
# ['unio ni']
# w zg
# ['wzg', 'wz g']
# żem nie
# ['że mnie']
# ae w
# ['a ew']
# aig i
# ['a igi']
# byś miał
# ['by śmiał']
# how to
# ['ho wto']
# ike nie
# ['i kenie']
# jezeli nie
# ['jez elinie']
# k ilka
# ['kilka', 'kil ka']
# l poseł
# ['lp oseł']
# na ryc .
# ['nary c.']
# orlen sa
# ['orle nsa']
# wieczora na
# ['wiec zorana']
# wtz w
# ['w tzw']
# w gok
# ['wg ok']
# w imie
# ['wimie', 'wim ie']
# żeś nie
# ['że śnie']
# argumentum ad
# ['argumentu mad']
# na prefinansowanie
# ['nap refinansowanie']
# proc .
# ['pro c.']
# p racownicy
# ['pracownicy']
# rr na
# ['r rna']
# w łososinie
# ['włos osinie']
# w ppe
# ['wp pe']
# z zso
# ['zz so']
# żebyś miała
# ['żeby śmiała']
# nie mialem
# ['niemi alem']
# sa oferuje
# ['sao feruje']
# wieczora nie
# ['wiec zoranie']
# z kks
# ['zk ks']
# d rużyna
# ['drużyna', 'dr użyna', 'druży na', 'drużyn a']
# no name
# ['nona me']
# o j
# ['oj']
# psp i
# ['ps pi']
# typu c
# ['ty puc', 'typ uc']
# w tfi
# ['wt fi']
# byc na
# ['by cna']
# bym po
# ['by mpo']
# b y
# ['by']
# co robic
# ['cor obic']
# l za
# ['lza', 'lz a']
# narazie to
# ['narazi eto']
# o nn
# ['on n']
# w edług
# ['według', 'we dług', 'wed ług']
# w tie
# ['wt ie']
# kiedyśmy się
# ['kiedyś mysię']
# ó w
# ['ów']
# si ę
# ['się']
# z old
# ['zol d']
# b lisko
# ['blisko']
# sa we
# ['saw e']
# zio w
# ['z iow']
# zle sie
# ['z lesie']
# z ulic .
# ['zuli c.']
# gdybyś miała
# ['gdyby śmiała']
# o czyms
# ['oczy ms']
# prezydenta george ’ a
# ['prezydenta george’a']
# in statu
# ['inst atu']
# nm i
# ['n mi']
# pojecia o
# ['poje ciao']
# w gu
# ['wg u']
# było dlań
# ['był odlań']
# byś w
# ['by św']
# hehe no
# ['he heno']
# nie moglam
# ['niemo glam']
# to jakis
# ['toja kis']
# w kuala
# ['wku ala']
# w olszewce
# ['wol szewce']
# za malo
# ['zam alo']
# centre for
# ['centr efor']
# harry ’ ego pottera
# ['harry’ego pottera']
# in an
# ['ina n']
# ju jitsu
# ['jujitsu']
# j eżeli
# ['jeżeli', 'je żeli', 'jeż eli', 'jeże li']
# na dzien
# ['nadzi en', 'nadzie n']
# no coz
# ['noc oz']
# p ierwszy
# ['pierwszy']
# sa tak
# ['s atak']
# to jakos
# ['toja kos']
# t rwają
# ['trwają', 'trwa ją']
# wiele bym
# ['wieleby m']
# za kazdym
# ['zakaz dym']
# a ndrzej
# ['andrzej']
# d zięki
# ['dzięki', 'dzięk i']
# motors i
# ['motor si']
# sie jakos
# ['sieja kos', 'siejak os']
# w lubiczu
# ['wlubi czu']
# a jo
# ['aj o']
# a propo
# ['ap ropo']
# c lub
# ['club']
# c nie
# ['cni e']
# do the
# ['dot he']
# moze z
# ['mo zez', 'moz ez']
# na parkitce
# ['napar kitce']
# polis oc .
# ['poliso c.']
# tfi na
# ['t fina']
# uke nie
# ['u kenie']
# ultra montana
# ['ultramontana', 'ul tramontana', 'ultramontan a']
# w psp
# ['wp sp']
# z mysłowic .
# ['zmysłowi c.']
# co bylo
# ['coby lo']
# debren nie
# ['de brennie']
# hong kongu
# ['hongkongu', 'hongkong u']
# j eden
# ['jeden', 'je den']
# j na
# ['jn a']
# na kazdym
# ['nakaz dym']
# troche za
# ['troch eza']
# up the
# ['upt he']
# w csw
# ['wc sw']
# z aig
# ['za ig']
# żebyś w
# ['żeby św']
# c k
# ['ck']
# heavy metal
# ['heavymetal']
# h r
# ['hr']
# k rzysztof
# ['krzysztof', 'krzy sztof']
# ma jakies
# ['maja kies', 'majaki es']
# mbp w
# ['mb pw']
# nie miala
# ['niemi ala']
# po iv
# ['poi v']
# s ł
# ['sł']
# to jo
# ['tojo']
# troche nie
# ['troc henie']
# uż w
# ['u żw']
# u j
# ['uj']
# w ptu
# ['wp tu']
# w zso
# ['wz so']
# back to
# ['bac kto']
# b yły
# ['były']
# chciała bym
# ['chciałabym', 'chciałaby m']
# ike i
# ['i kei']
# jak 2
# ['ja k2']
# j estem
# ['jestem', 'jest em']
# l ustawy
# ['lu stawy']
# na moj
# ['nam oj']
# of o
# ['o fo']
# ogole to
# ['o goleto', 'ogol eto']
# polską sa
# ['pol skąsa']
# sa nr
# ['san r']
# vi do
# ['v ido']
# w unfe
# ['wun fe']
# ale narazie
# ['alena razie']
# czy the
# ['czyt he']
# gdzies w
# ['gdzie sw']
# jacobbs a
# ['jacob bsa']
# l prezydent
# ['lp rezydent']
# on line
# ['online']
# o source
# ['oso urce']
# piątek 2
# ['piąte k2']
# reiki w
# ['rei kiw']
# rsa w
# ['r saw']
# wgi dom
# ['w gidom', 'wg idom']
# w amplico
# ['wam plico', 'wamp lico']
# asiekwil a
# ['asiek wila']
# byś miała
# ['by śmiała']
# do ppe
# ['dop pe']
# hard rock
# ['hardrock']
# heavy metalu
# ['heavymetalu', 'heavymetal u']
# ja poprostu
# ['japo prostu']
# kgw z
# ['kg wz']
# l adam
# ['la dam', 'lad am', 'lada m']
# ł ódzki
# ['łódzki']
# mi ktos
# ['mik tos']
# p ięć
# ['pięć']
# żebym po
# ['żeby mpo']
# gdybym z
# ['gdyby mz']
# have to
# ['ha veto']
# jakbyś miała
# ['jakby śmiała']
# ja narazie
# ['jana razie']
# knf i
# ['k nfi']
# m iejski
# ['miejski', 'miej ski']
# n awet
# ['nawet', 'na wet', 'naw et']
# piłkarze mkp
# ['piłkarzem kp']
# rownie dobrze
# ['row niedobrze']
# r eprezentacja
# ['reprezentacja', 're prezentacja']
# ś po
# ['śp o']
# wrocławiu l
# ['wrocławi ul']
# chciał bym
# ['chciałbym', 'chciałby m']
# de charny
# ['dec harny']
# do zycia
# ['dozy cia']
# gdybym ich
# ['gdyby mich']
# ispa w
# ['i spaw', 'is paw']
# i andrew
# ['ian drew']
# i mr
# ['im r']
# i nel
# ['in el']
# mozna to
# ['moz nato']
# of art
# ['o fart']
# of list
# ['oflis t']
# poland z
# ['polan dz']
# sa a
# ['saa', 's aa']
# to jakies
# ['toja kies']
# t omasz
# ['tomasz', 'to masz', 'tomas z']
# unfe na
# ['un fena']
# w iele
# ['wiele', 'wie le']
# w onecie
# ['won ecie']
# zastanow sie
# ['zastano wsie']
# z ktora
# ['zk tora']
# bylem w
# ['byle mw']
# c ztery
# ['cztery', 'cz tery']
# in spe
# ['insp e']
# i mowi
# ['im owi']
# kiedys w
# ['kiedy sw']
# krp w
# ['kr pw']
# m ecz
# ['mecz', 'me cz', 'mec z']
# na stade
# ['nasta de']
# nn w
# ['n nw']
# no more
# ['nomo re']
# obwe w
# ['ob wew']
# progress i
# ['progres si']
# reiki na
# ['rei kina']
# wsa w
# ['w saw']
# w umig
# ['wu mig']
# byc ze
# ['bycze', 'bycz e']
# byla to
# ['by lato']
# ciala nie
# ['ci alanie', 'cia lanie']
# come back
# ['comeback']
# gp w
# ['g pw']
# hong kong
# ['hongkong']
# jakbym z
# ['jakby mz']
# k ażdy
# ['każdy']
# p rzedstawiciele
# ['przedstawiciele', 'przedstawi ciele', 'przedstawicie le', 'przedstawiciel e']
# w reality
# ['wre ality']
# za nia
# ['z ania']
# a f
# ['af']
# a iv
# ['ai v']
# do ike
# ['doi ke']
# g rupa
# ['grupa', 'gr upa', 'grup a']
# i pbuk
# ['ip buk']
# jakos sie
# ['jak ossie', 'jako ssie']
# j ego
# ['jego', 'je go']
# moze za
# ['mo zeza', 'moz eza']
# na swoj
# ['nas woj']
# of an
# ['o fan']
# osiem l
# ['osie ml']
# pan nieczaj
# ['pannie czaj']
# saldo wn
# ['sal down']
# uva i
# ['uv ai']
# vi b
# ['v ib']
# witaminę c .
# ['witaminę c.']
# w ielu
# ['wielu', 'wie lu']
# ale coz
# ['alec oz']
# byla w
# ['by law']
# bym od
# ['by mod']
# hmm a
# ['hm ma']
# jeżeli bym
# ['jeżeliby m']
# krzysztof oremus
# ['krzysztofo remus']
# ktora nie
# ['k toranie', 'kto ranie']
# ktora sie
# ['kto rasie']
# le goff
# ['leg off']
# maj ą
# ['mają', 'ma ją']
# mowi sie
# ['mo wisie']
# ping an
# ['pi ngan', 'pin gan']
# sa otrzymało
# ['sao trzymało']
# ucze się
# ['u czesię']
# us air
# ['usa ir']
# w gg
# ['wg g']
# w swiecie
# ['ws wiecie']
# w tbs
# ['wt bs']
# aig nie
# ['ai gnie']
# bawie sie
# ['ba wiesie', 'bawi esie']
# fap i
# ['fa pi']
# if i
# ['i fi']
# influences on
# ['influence son']
# jeśli bym
# ['jeśliby m']
# j ej
# ['jej']
# łososina dolna
# ['łososi nadolna']
# na orawie
# ['naora wie']
# sa wprowadziło
# ['saw prowadziło']
# se ne
# ['sen e']
# union w
# ['unio nw']
# w ecole
# ['we cole']
# w iększość
# ['większość']
# z aks
# ['za ks']
# a skad
# ['as kad']
# foto models
# ['fotomodel s']
# from a
# ['fr oma']
# gdybym po
# ['gdyby mpo']
# grupa f
# ['grup af']
# handlowego sa
# ['handlowe gosa']
# i psp
# ['ip sp']
# kgs i
# ['kg si']
# kings of
# ['king sof']
# k l
# ['kl']
# l oraz
# ['lo raz', 'lor az', 'lora z']
# mba w
# ['m baw']
# mtb w
# ['mt bw']
# nie mow
# ['niem ow', 'niemo w']
# vi sp
# ['vis p']
# w łaściciele
# ['właściciele', 'właści ciele', 'właściciel e']
# w pln
# ['wp ln']
# żebym o
# ['żeby mo']
# abyś w
# ['aby św']
# ale jezeli
# ['aleje zeli']
# ciech nie
# ['cie chnie']
# d zieci
# ['dzieci', 'dziec i']
# filar sa
# ['fi larsa', 'fil arsa']
# f e
# ['fe']
# i dzieki
# ['idzie ki']
# klasa c
# ['klas ac']
# l przez
# ['lp rzez', 'lpr zez']
# name is
# ['nam eis']
# na miesiac
# ['namiesi ac']
# niz z
# ['ni zz']
# pana giereja
# ['panagie reja']
# pln w
# ['pl nw']
# polonia sa
# ['polo niasa']
# p iotr
# ['piotr']
# p olski
# ['polski', 'pol ski', 'polsk i']
# sa wynosi
# ['sawy nosi']
# sie ktos
# ['siek tos']
# the man
# ['thema n']
# tośmy się
# ['toś mysię']
# to wogóle
# ['tow ogóle']
# troche i
# ['trochei', 't rochei']
# wstalam i
# ['w stalami', 'ws talami']
# w grazu
# ['wg razu']
# zss w
# ['zs sw']
# z ł
# ['zł']
# a little
# ['alit tle']
# choćbym nie
# ['choćby mnie']
# gdybyś w
# ['gdyby św']
# g ł
# ['gł']
# hehe nie
# ['he henie']
# h e
# ['he']
# iduna życie
# ['idu nażycie']
# i ch
# ['ich']
# i ł
# ['ił']
# kramm i
# ['kram mi']
# ktora ma
# ['kto rama']
# niz na
# ['ni zna']
# obama nie
# ['ob amanie', 'oba manie']
# php w
# ['ph pw']
# post scriptum
# ['postscriptum']
# sa jan
# ['sajan', 'saja n']
# sa lub
# ['sal ub', 'salu b']
# takie sa
# ['ta kiesa']
# was ist
# ['wasi st']
# w casa
# ['wc asa']
# w ochojcu
# ['woch ojcu']
# z mmks
# ['zm mks']
# z naprzodem
# ['zna przodem']
# żebym im
# ['żeby mim']
# abym z
# ['aby mz']
# b ył
# ['był']
# code w
# ['cod ew']
# do ktorej
# ['doktor ej']
# f a
# ['fa']
# gg nie
# ['g gnie']
# hmm nie
# ['hm mnie']
# jak bylam
# ['jakby lam']
# ja myśle
# ['jamy śle']
# klasy c .
# ['klasy c.']
# m amy
# ['mamy', 'ma my']
# na swiat
# ['nas wiat']
# nie widac
# ['niewid ac']
# prosze nie
# ['proszenie', 'p roszenie', 'pr oszenie', 'pros zenie', 'proszeni e']
# przygód harry ’ ego
# ['przygód harry’ego']
# ptc i
# ['pt ci']
# sa gdynia
# ['sag dynia']
# sa jak
# ['saj ak', 'saja k']
# s zkoła
# ['szkoła']
# the moon
# ['themo on']
# to jakas
# ['toja kas']
# typu c .
# ['typu c.']
# ue l
# ['u el']
# wipo o
# ['wip oo']
# w calej
# ['wc alej']
# w gpp
# ['wg pp']
# w ł
# ['wł']
# w usd
# ['wu sd']
# zle i
# ['z lei']
# aaa i
# ['aa ai']
# apple w
# ['ap plew']
# cu pte
# ['cup te']
# czy jakos
# ['czyja kos']
# firma x
# ['fir max']
# henryk iv
# ['henryki v']
# i nnw
# ['in nw']
# i owiec .
# ['iowie c.']
# jak bys
# ['jakby s']
# j erzy
# ['jerzy']
# j nie
# ['jn ie']
# korzystac z
# ['korzy stacz', 'korzysta cz']
# l artur
# ['lar tur']
# l ii
# ['li i']
# l roman
# ['lr oman']
# m ieszkaniec
# ['mieszkaniec']
# na kogos
# ['nako gos']
# nie miec
# ['niemiec']
# ok 2
# ['o k2']
# owu będą
# ['ow ubędą']
# sa jakies
# ['saja kies']
# soba i
# ['so bai', 'sob ai']
# time to
# ['tim eto']
# ty żeś
# ['tyż eś']
# udalo sie
# ['uda losie']
# vi a
# ['via']
# vi na
# ['vina', 'v ina', 'vin a']
# vi z
# ['v iz']
# wyglada na
# ['wyg ladana']
# z dru
# ['zdr u']
# z mkp
# ['zm kp']
# andrzeja zolla
# ['andrzej azolla']
# a jd
# ['aj d']
# dzien i
# ['dzieni']
# d l
# ['dl']
# d wóch
# ['dwóch']
# gdynia sa
# ['gdy niasa', 'gdyni asa']
# hajto i
# ['haj toi']
# iqs and
# ['iq sand']
# jak bylo
# ['jakby lo']
# j an
# ['jan', 'ja n']
# k ierowcy
# ['kierowcy', 'kier owcy']
# l anna
# ['lan na']
# l mam
# ['lm am']
# motors w
# ['motor sw']
# mozna w
# ['moz naw']
# na pare
# ['napa re', 'napar e']
# nie lubia
# ['nielubi a']
# nn i
# ['n ni']
# n ajpierw
# ['najpierw']
# pani c .
# ['pani c.']
# piela w
# ['pie law']
# poland nie
# ['polan dnie']
# p an
# ['pan', 'pa n']
# sie komus
# ['siekom us']
# sposob na
# ['sposobna', 's posobna', 'sp osobna']
# to dlań
# ['t odlań']
# union sa
# ['unio nsa']
# w ike
# ['wik e']
# w ojciech
# ['wojciech']
# w ugim
# ['wu gim']
# w uks
# ['wu ks']
# zdarzaja sie
# ['zdarza jasie', 'zdarzaj asie']
# z awodnicy
# ['zawodnicy', 'za wodnicy']
# z zsg
# ['zz sg']
# be the
# ['bet he']
# choćbyś nie
# ['choćby śnie']
# dbac o
# ['d baco', 'dba co']
# dk w
# ['d kw']
# doroti no
# ['doro tino', 'dorot ino']
# doszlo do
# ['dosz lodo']
# gdzie niegdzie
# ['gdzieniegdzie']
# heh a
# ['he ha']
# hic et
# ['hi cet']
# ike to
# ['i keto']
# jakże bym
# ['jakżeby m']
# je ne
# ['jen e']
# jo nie
# ['jonie', 'jon ie', 'joni e']
# j n
# ['jn']
# kocurekola no
# ['kocurek olano']
# krzysztof c .
# ['krzysztof c.']
# ktos to
# ['kto sto']
# k omisja
# ['komisja', 'komis ja']
# k oszykarze
# ['koszykarze', 'koszy karze', 'koszyk arze', 'koszykarz e']
# l oleju
# ['lo leju']
# mysl o
# ['my slo']
# naprawde sie
# ['napraw desie']
# pracy l
# ['pr acyl']
# prezes aig
# ['prezesa ig']
# p aweł
# ['paweł', 'paw eł']
# p l
# ['pl']
# sa posiada
# ['sap osiada', 'sapo siada']
# senator stokarska
# ['senators tokarska']
# sie czegos
# ['siecze gos']
# the mars
# ['them ars']
# videograf ii
# ['v ideografii', 'video grafii']
# wizz air
# ['wiz zair']
# w ałma
# ['wał ma']
# w krótce
# ['wkrótce']
# za free
# ['zafr ee']
# z zg
# ['zz g']
# z zss
# ['zz ss']
# żebym i
# ['żeby mi']
# aegon i
# ['a egoni']
# ale żeś
# ['ależ eś']
# a bym
# ['aby m']
# a twin
# ['at win']
# choćmy się
# ['choć mysię']
# czyżbyś nie
# ['czyżby śnie']
# c hodzi
# ['chodzi']
# dame w
# ['da mew', 'dam ew']
# de jong
# ['dejon g']
# do tfi
# ['dot fi']
# europe w
# ['europ ew']
# for you
# ['fory ou']
# i moj
# ['im oj']
# i narazie
# ['ina razie']
# jesz cze
# ['jeszcze']
# john c .
# ['john c.']
# kks kalisz
# ['kk skalisz']
# kks prosna
# ['kk sprosna']
# like to
# ['li keto', 'lik eto']
# longin komołowski
# ['longinkom ołowski']
# l wiceprezydent
# ['lwice prezydent']
# l zarząd
# ['lza rząd']
# mowi o
# ['mo wio']
# na dworzu
# ['nadworzu']
# na ppe
# ['nap pe', 'napp e']
# nia nie
# ['nianie', 'n ianie', 'ni anie', 'niani e']
# nie jakies
# ['niejaki es', 'niejakie s']
# potrafie sie
# ['potrafi esie']
# p olska
# ['polska', 'pol ska', 'polsk a']
# rpp i
# ['rp pi']
# rpp nie
# ['rp pnie']
# sa juz
# ['saj uz', 'saju z']
# ś l
# ['śl']
# the most
# ['themo st']
# to robic
# ['tor obic']
# usd z
# ['us dz']
# venus i
# ['venu si']
# wola sa
# ['w olasa', 'wol asa']
# w open
# ['wop en']
# z akończył
# ['zakończył', 'za kończył']
# z amplico
# ['zam plico']
# żebym ich
# ['żeby mich']
# a gdym
# ['ag dym']
# a nna
# ['anna', 'ann a']
# a ńania
# ['ań ania']
# a ś
# ['aś']
# bede w
# ['bed ew']
# do ktorego
# ['doktor ego']
# du bist
# ['dubi st']
# dyrektor zso
# ['dyrektorz so']
# d opiero
# ['dopiero']
# faux pas
# ['fauxpas']
# f unkcjonariusze
# ['funkcjonariusze', 'funkcjonariusz e']
# home banking
# ['homebanking']
# i angus
# ['ian gus']
# i prokom
# ['ip rokom']
# i pz
# ['ip z']
# j anusz
# ['janusz']
# ktory nie
# ['kto rynie']
# l wydział
# ['lwy dział']
# ma swoj
# ['mas woj']
# od l
# ['o dl']
# podobaja sie
# ['podoba jasie', 'podobaj asie']
# powiedziec o
# ['powiedzie co']
# p ierwsza
# ['pierwsza', 'pierw sza']
# sa wyniósł
# ['sawy niósł']
# szef abw
# ['szefa bw']
# troche to
# ['troch eto']
# ukosa i
# ['ukos ai']
# utro w
# ['ut row']
# willy ’ ego brandta
# ['willy’ego brandta']
# wup w
# ['wu pw']
# w ciechu
# ['wciec hu']
# w uk
# ['wu k']
# zapomniec o
# ['zapomni eco', 'zapomnie co']
# z andrew
# ['zan drew', 'zandr ew']
# as you
# ['asy ou']
# chodzic na
# ['chodzi cna']
# do gp
# ['dog p']
# eur i
# ['e uri']
# fap w
# ['fa pw']
# f irma
# ['firma', 'fir ma', 'firm a']
# gp i
# ['g pi']
# grzegorz c .
# ['grzegorz c.']
# hmi w
# ['hm iw']
# instytut yad
# ['instytuty ad']
# i sun
# ['is un']
# jo to
# ['joto', 'jot o']
# kazen i
# ['ka zeni']
# kick boxingu
# ['kickboxingu', 'kickboxing u']
# l dla
# ['ldl a']
# l ewa
# ['lewa', 'le wa', 'lew a']
# l marian
# ['lm arian']
# ł ódzka
# ['łódzka']
# moze mnie
# ['mo zemnie']
# moze na
# ['m ozena']
# my life
# ['myli fe']
# na palenicy
# ['napa lenicy']
# na thanedd
# ['nathan edd']
# nie mowi
# ['niem owi']
# n asz
# ['nasz', 'nas z']
# o soby
# ['osoby', 'os oby', 'oso by']
# pbc i
# ['pb ci']
# robic z
# ['ro bicz', 'robi cz']
# sa działa
# ['sad ziała']
# spi data
# ['spid ata', 'spida ta']
# the main
# ['thema in']
# the table
# ['thet able']
# to make
# ['toma ke']
# unfe nie
# ['un fenie']
# w pz
# ['wp z']
# w ydział
# ['wydział', 'wy dział', 'wyd ział']
# ze zu
# ['zez u']
# zg rudna
# ['z grudna']
# z golden
# ['zgol den']
# że the
# ['żet he']
# abyś miał
# ['aby śmiał']
# and you
# ['andy ou']
# an der
# ['and er']
# arts w
# ['art sw']
# a good
# ['ago od']
# a moj
# ['am oj']
# a sa
# ['asa', 'as a']
# bedziemy sie
# ['bedzie mysie']
# boys i
# ['boy si']
# b c
# ['bc']
# can i
# ['ca ni']
# da costa
# ['d acosta']
# du bois
# ['dubois']
# e ś
# ['eś']
# g l
# ['gl']
# ispa na
# ['is pana']
# i like
# ['ili ke']
# i nfz
# ['inf z']
# k ilkanaście
# ['kilkanaście', 'kil kanaście', 'kilka naście']
# k oszykarki
# ['koszykarki', 'koszy karki', 'koszyk arki']
# legis w
# ['legi sw']
# mozna było
# ['moz nabyło']
# mozna tak
# ['moz natak']
# n iemal
# ['niemal', 'nie mal', 'niem al']
# open z
# ['o penz']
# o jakies
# ['oja kies']
# pojawiaja sie
# ['pojawia jasie', 'pojawiaj asie']
# polski ś
# ['pol skiś']
# poste restante
# ['posterestante']
# pro musica
# ['promu sica']
# rotch i
# ['rot chi']
# sa ludzie
# ['sal udzie']
# sa tu
# ['s atu']
# sun i
# ['suni', 'su ni']
# syn arana
# ['syna rana']
# terms of
# ['term sof']
# to rowniez
# ['torowni ez']
# t eraz
# ['teraz', 'te raz', 'ter az', 'tera z']
# uczyc na
# ['uczy cna']
# unitas i
# ['unit asi', 'unita si']
# w eur
# ['we ur']
# w szystkie
# ['wszystkie']
# w yad
# ['wy ad']
# zrobic z
# ['zrobi cz']
# z nany
# ['znany']
# z skl
# ['zs kl']
# asiekwil nie
# ['asiek wilnie']
# auto moto
# ['autom oto']
# bo moj
# ['bom oj']
# byla by
# ['by laby']
# co sa
# ['cos a']
# c złonkowie
# ['członkowie', 'członko wie', 'członkowi e']
# d ziałacze
# ['działacze', 'działacz e']
# hard rocka
# ['hardrocka', 'hardrock a']
# i choc
# ['ich oc']
# i dac
# ['id ac']
# ja jakos
# ['jaja kos']
# ja kiedys
# ['jakie dys']
# jednak 2
# ['jedna k2']
# krok 2
# ['kro k2']
# ktorego nie
# ['kto regonie']
# ma jakis
# ['maja kis', 'majak is', 'majaki s']
# ma ktos
# ['mak tos']
# mock usiadł
# ['mocku siadł']
# mozna na
# ['mo znana']
# nie myle
# ['niemy le']
# od groma
# ['odgrom a']
# oke w
# ['ok ew']
# piotr c .
# ['piotr c.']
# poprostu jest
# ['poprostuje st']
# prezes urt
# ['prezesur t']
# psz na
# ['ps zna']
# p rawdopodobnie
# ['prawdopodobnie', 'prawdo podobnie', 'prawdopodobni e']
# road w
# ['ro adw']
# robert c .
# ['robert c.']
# słowy nie
# ['s łowynie']
# to ktos
# ['tok tos']
# vi nie
# ['vinie', 'v inie', 'vin ie']
# wagura i
# ['wag urai', 'wagu rai']
# work and
# ['worka nd']
# w dołubowie
# ['wdo łubowie']
# w gw
# ['wg w']
# w interii
# ['winter ii']
# w netii
# ['wnet ii']
# zalot w
# ['zalo tw']
# z inteligo
# ['zin teligo']
# że rpp
# ['żer pp']
# aaa no
# ['aa ano']
# are not
# ['aren ot', 'areno t']
# argumentum a
# ['argumentu ma']
# asiekwil no
# ['asiek wilno']
# bode miller
# ['bodem iller']
# b yć
# ['być']
# cool i
# ['co oli']
# costa i
# ['co stai', 'cos tai']
# cytochromu c
# ['cytochrom uc']
# czesto nie
# ['cz estonie', 'czes tonie']
# czesto sie
# ['czes tosie']
# d ł
# ['dł']
# e ł
# ['eł']
# face to
# ['facet o']
# gdybym o
# ['gdyby mo']
# góra j
# ['góraj', 'gór aj']
# imo że
# ['i może']
# j edna
# ['jedna', 'je dna']
# kase na
# ['ka sena']
# ktos tu
# ['k tostu', 'kto stu']
# l ekarze
# ['lekarze', 'le karze', 'lek arze', 'lekarz e']
# l ile
# ['li le']
# l wyniki
# ['lwy niki']
# ł odzianie
# ['łodzianie', 'łodzi anie', 'łodzian ie']
# moge z
# ['mo gez']
# mos słupca
# ['moss łupca']
# na costa
# ['n acosta']
# o nia
# ['oni a']
# pour le
# ['po urle']
# pzla na
# ['p zlana']
# ra i
# ['rai', 'r ai']
# rotcha i
# ['rot chai']
# rozmawiac z
# ['rozmawiacz', 'rozmawia cz']
# rpp w
# ['rp pw']
# series w
# ['serie sw']
# smuda nie
# ['sm udanie']
# soto w
# ['so tow', 'sot ow']
# s ezon
# ['sezon', 'se zon']
# s f
# ['sf']
# s iatkarze
# ['siatkarze', 'siat karze', 'siatkarz e']
# s ześć
# ['sześć']
# to żeś
# ['toż eś']
# troche w
# ['troch ew']
# try miga
# ['trymiga', 'trym iga']
# t ydzień
# ['tydzień', 'ty dzień']
# ze zle
# ['zez le']
# aaa a
# ['aa aa']
# abym i
# ['aby mi']
# andrzej c .
# ['andrzej c.']
# bys sie
# ['byssie', 'by ssie', 'byss ie']
# capital i
# ['capi tali']
# ciech i
# ['cie chi', 'ciec hi']
# c hociaż
# ['chociaż']
# c zterech
# ['czterech']
# do cu
# ['doc u']
# du du
# ['dudu', 'd udu', 'dud u']
# du pont
# ['dupo nt']
# dyrektor zgm
# ['dyrektorz gm']
# d wadzieścia
# ['dwadzieścia']
# d yrektor
# ['dyrektor', 'dyrek tor']
# fudali i
# ['fu dalii']
# gdańskiego sa
# ['gdańskie gosa']
# i blue
# ['ibl ue']
# i ika
# ['ii ka']
# i les
# ['ile s']
# jak sa
# ['jaksa']
# jak żem
# ['jakże m']
# komus sie
# ['komu ssie']
# k ibice
# ['kibice', 'kibic e']
# legis i
# ['legi si']
# l ma
# ['lm a']
# l maria
# ['lm aria']
# macie jakies
# ['macieja kies', 'maciejaki es']
# mi troche
# ['mitro che']
# na gądowie
# ['nagą dowie']
# nie mialo
# ['niemi alo']
# nie mogl
# ['niemo gl']
# n iedawno
# ['niedawno', 'nie dawno']
# owu w
# ['ow uw']
# o kims
# ['oki ms']
# pisac o
# ['pisa co']
# play out
# ['p layout']
# przemysłu sa
# ['przemysł usa']
# pubp w
# ['pub pw']
# p ięciu
# ['pięciu']
# p olscy
# ['polscy']
# rs i
# ['r si']
# s tanisław
# ['stanisław']
# s tudenci
# ['studenci']
# tak ogolnie
# ['tako golnie']
# t eatr
# ['teatr']
# t ym
# ['tym', 'ty m']
# uke na
# ['u kena']
# w erfurcie
# ['wer furcie']
# w gre
# ['wg re']
# w leźnicy
# ['wleź nicy']
# w spzoz
# ['wsp zoz']
# w szyscy
# ['wszyscy']
# ze twoj
# ['zet woj']
# że rft
# ['żer ft']
# że tfi
# ['żet fi']
# ż eby
# ['żeby', 'że by']
# all i
# ['al li']
# bośmy się
# ['boś mysię']
# byc i
# ['by ci']
# byc za
# ['bycza', 'bycz a']
# b urmistrz
# ['burmistrz', 'bur mistrz']
# ciazy to
# ['cia zyto']
# czegos w
# ['czego sw']
# czekac na
# ['czeka cna']
# di w
# ['diw', 'd iw']
# do kc .
# ['dok c.']
# dru i
# ['d rui']
# energetycznego sa
# ['energetyczne gosa']
# e f
# ['ef']
# from my
# ['frommy']
# f oraz
# ['fo raz', 'for az', 'fora z']
# gmo w
# ['gm ow']
# hat trick
# ['hattrick']
# iduna w
# ['idu naw']
# il faut
# ['ilf aut', 'ilfa ut']
# imprezke i
# ['imprez kei']
# ispa i
# ['is pai']
# jakbyś w
# ['jakby św']
# j po
# ['jp o']
# ktore w
# ['kto rew']
# ktos w
# ['kto sw']
# leszek c .
# ['leszek c.']
# leszka c .
# ['leszka c.']
# l urząd
# ['lu rząd']
# łososinie dolnej
# ['łososi niedolnej']
# martwie sie
# ['mart wiesie', 'martwi esie']
# milena rachid
# ['milen arachid']
# mna nie
# ['mn anie']
# mock w
# ['moc kw']
# m uzeum
# ['muzeum']
# n ajbardziej
# ['najbardziej', 'najbar dziej']
# onetu i
# ['on etui', 'one tui']
# pan y
# ['pany']
# porozmawiac z
# ['po rozmawiacz', 'porozmawia cz']
# ppe nie
# ['p penie']
# p ieniądze
# ['pieniądze', 'pieniądz e']
# p owiatowy
# ['powiatowy', 'powiat owy']
# roberta chomy
# ['robertach omy']
# robia to
# ['r obiato', 'rob iato']
# sa należy
# ['sana leży']
# sa wraz
# ['saw raz']
# sdpl z
# ['sdp lz']
# sie czyms
# ['sieczy ms']
# sie jakis
# ['sieja kis', 'siejak is', 'siejaki s']
# stk w
# ['st kw']
# s tarostwo
# ['starostwo', 'starostw o']
# ś może
# ['śmo że']
# tadeusz c .
# ['tadeusz c.']
# takze w
# ['tak zew']
# troche na
# ['troc hena']
# troche z
# ['troch ez']
# t ę
# ['tę']
# t uż
# ['tuż']
# ubs w
# ['ub sw']
# uks w
# ['uksw']
# w abw
# ['wa bw', 'wab w']
# w kdk
# ['wkd k']
# w zgm
# ['wz gm', 'wzg m']
# z nzoz
# ['zn zoz']
# agp w
# ['ag pw']
# anna c .
# ['anna c.']
# arthur c .
# ['arthur c.']
# bari i
# ['barii', 'b arii', 'bar ii']
# bartos złożył
# ['bartosz łożył']
# byl on
# ['by lon']
# b ędzie
# ['będzie']
# b yła
# ['była', 'był a']
# centre w
# ['cent rew', 'centr ew']
# co dzien
# ['codzie n']
# do ciechu
# ['dociec hu']
# dyrektor zzoz
# ['dyrektorz zoz']
# dzien na
# ['dzienna']
# gdybym od
# ['gdyby mod']
# g rzegorz
# ['grzegorz']
# hard core
# ['hardcore']
# hromadko i
# ['hromad koi']
# igor kałat
# ['igorka łat']
# in die
# ['indie', 'ind ie']
# i doc .
# ['ido c.']
# i ge
# ['ig e']
# i ggadam
# ['ig gadam']
# i ktos
# ['ikt os']
# i mass
# ['ima ss']
# i noon
# ['ino on']
# i tfi
# ['it fi']
# i ż
# ['iż']
# jakbym po
# ['jakby mpo']
# jezeli to
# ['jez elito']
# j acek
# ['jacek', 'ja cek', 'jace k']
# kick boxing
# ['kickboxing']
# k c
# ['kc']
# l edward
# ['led ward']
# l mariusz
# ['lm ariusz']
# l udzie
# ['ludzie', 'ludzi e']
# l wiceprezes
# ['lwice prezes']
# l wiesław
# ['lwie sław']
# łukoil i
# ['łuko ili']
# ł ódzcy
# ['łódzcy']
# mozna go
# ['moz nago']
# m aciej
# ['maciej', 'maci ej']
# m iasto
# ['miasto', 'miast o']
# m inisterstwo
# ['ministerstwo', 'ministerstw o']
# na gare
# ['naga re', 'nagar e']
# na wiec .
# ['nawie c.']
# non agit
# ['nona git']
# olo nie
# ['o lonie']
# o statnie
# ['ostatnie', 'ostatni e']
# o statnio
# ['ostatnio', 'ostatni o']
# popiela i
# ['popie lai', 'popiel ai']
# ppe na
# ['p pena']
# ppe z
# ['pp ez']
# przy psp
# ['przyp sp']
# p odopieczni
# ['podopieczni']
# p roblem
# ['problem', 'prob lem']
# rafako i
# ['rafa koi']
# rafako sa
# ['rafa kosa']
# r obert
# ['robert', 'ro bert', 'rober t']
# r yszard
# ['ryszard']
# sprawe z
# ['spraw ez']
# to dzieki
# ['todzie ki']
# t akże
# ['także', 'tak że']
# uks i
# ['u ksi']
# wyrok sa
# ['wy roksa', 'wyr oksa']
# w arminii
# ['war minii']
# w bks
# ['wbk s']
# w daszynie
# ['wda szynie']
# w ecg
# ['we cg']
# w ge
# ['wg e']
# w gizie
# ['wg izie']
# w grom-ie
# ['wg rom-ie']
# w mops-ie
# ['wmo ps-ie']
# w tykocinie
# ['wtyko cinie']
# w zaden
# ['wz aden', 'wza den']
# zawodnik uks
# ['zawodni kuks', 'zawodniku ks']
# za mna
# ['zam na']
# zle nie
# ['z lenie']
# żem w
# ['że mw']
# agora sa
# ['ago rasa', 'agor asa']
# aig na
# ['ai gna']
# analityk open
# ['analityko pen']
# arts and
# ['art sand']
# auchan i
# ['a uchani']
# a zreszta
# ['az reszta']
# bede na
# ['b edena']
# bo bylam
# ['boby lam']
# bo jo
# ['bojo', 'boj o']
# czeka nań
# ['czekan ań', 'czekana ń']
# c zęść
# ['część']
# de fer
# ['def er']
# de lopitala
# ['del opitala']
# dodac ze
# ['do dacze']
# dp w
# ['d pw']
# drugs and
# ['drug sand']
# d laczego
# ['dlaczego', 'dla czego']
# d ziesięć
# ['dziesięć']
# elektryk iv
# ['elektryki v']
# ga i
# ['gai', 'g ai']
# heros sa
# ['he rossa', 'her ossa']
# iia i
# ['ii ai']
# itb w
# ['it bw']
# i see
# ['is ee']
# i skl
# ['is kl']
# i żeś
# ['iż eś']
# jakos to
# ['jako sto']
# kiedys to
# ['kiedy sto']
# kramm a
# ['kram ma']
# k siądz
# ['ksiądz']
# liczyc na
# ['liczy cna']
# l mleka
# ['lm leka']
# ł ódzkie
# ['łódzkie', 'łódzki e']
# mariusza c .
# ['mariusza c.']
# moze on
# ['moz eon']
# m ichał
# ['michał', 'mi chał']
# nad iną
# ['na diną']
# narazie sie
# ['narazi esie']
# nota f
# ['no taf', 'not af']
# omalże nie
# ['oma lżenie', 'omal żenie']
# oraz c .
# ['oraz c.']
# o siem
# ['osiem', 'osi em', 'osie m']
# paweł c .
# ['paweł c.']
# po społu
# ['pospołu']
# prosze cie
# ['pros zecie']
# przeciez na
# ['przecie zna']
# psse w
# ['pss ew']
# public enemy
# ['publice nemy']
# p olskie
# ['polskie', 'polsk ie', 'polski e']
# p owiat
# ['powiat', 'po wiat', 'pow iat']
# real users
# ['realu sers']
# ruchowo l
# ['rucho wol']
# sa musi
# ['samu si']
# services i
# ['service si']
# stanisław alot
# ['stanisława lot']
# strony x
# ['str onyx']
# sule i
# ['su lei']
# s trażacy
# ['strażacy']
# temi w
# ['tem iw']
# to j
# ['t oj']
# to malo
# ['tom alo', 'toma lo']
# to see
# ['tos ee']
# to zaden
# ['toz aden']
# we wleniu
# ['wew leniu']
# when i
# ['w heni']
# wiecej w
# ['wiece jw']
# wma i
# ['w mai']
# w doha
# ['wdo ha']
# w dw
# ['wdw']
# w empik-u
# ['we mpik-u']
# w inteligo
# ['win teligo']
# w kumace
# ['wku mace']
# w opk
# ['wop k']
# w santo
# ['ws anto']
# w swiss
# ['wsw iss']
# w ymce
# ['wym ce']
# ze kazda
# ['zeka zda']
# zst w
# ['zs tw']
# zu w
# ['z uw']
# z abw
# ['za bw']
# z bigniew
# ['zbigniew']
# z łososiny
# ['zło sosiny']
# z myślenic .
# ['zmyśleni c.']
# ale jo
# ['alejo', 'a lejo', 'alej o']
# aol i
# ['a oli']
# arthura c .
# ['arthura c.']
# a kcja
# ['akcja']
# back in
# ['bac kin']
# bede z
# ['bed ez']
# bo napewno
# ['bona pewno']
# bo narazie
# ['bona razie', 'bonar azie']
# bylo nie
# ['by lonie']
# byl z
# ['by lz']
# co kolwiek
# ['cokolwiek']
# czwartek 2
# ['czwarte k2']
# czy iv
# ['czyi v']
# do gg
# ['dog g']
# do tie
# ['dot ie']
# du tout
# ['dut out', 'duto ut']
# for an
# ['fo ran', 'fora n']
# f undacja
# ['fundacja']
# gg na
# ['g gna']
# gmo i
# ['g moi']
# greenberg i
# ['green bergi']
# holta i
# ['hol tai']
# idée fixe
# ['idéefixe']
# isa nie
# ['i sanie', 'is anie']
# isc z
# ['is cz']
# i dorothy
# ['ido rothy']
# i niewiem
# ['inie wiem']
# i robic
# ['ir obic']
# jo cie
# ['jocie']
# jo jo
# ['jojo', 'joj o']
# j ednym
# ['jednym']
# j esteśmy
# ['jesteśmy', 'jesteś my']
# karwan i
# ['ka rwani', 'kar wani']
# kg l
# ['k gl']
# kiedys o
# ['kiedy so']
# kiedys sie
# ['kiedy ssie']
# ktorej sie
# ['kto rejsie']
# ku klux
# ['kuk lux']
# k iedyś
# ['kiedyś', 'kie dyś']
# k ilkadziesiąt
# ['kilkadziesiąt']
# k omenda
# ['komenda', 'komend a']
# k onkurs
# ['konkurs']
# let the
# ['lett he']
# l wiceprzewodniczący
# ['lwice przewodniczący']
# ło matko
# ['łom atko']
# mam robic
# ['mamr obic']
# marian c .
# ['marian c.']
# maxa i
# ['max ai']
# mba na
# ['m bana']
# mc donalda
# ['mcdonalda', 'mcdonald a']
# mike nie
# ['mi kenie']
# mock usłyszał
# ['mocku słyszał']
# m arcin
# ['marcin', 'marc in', 'marci n']
# m iłośnicy
# ['miłośnicy', 'miło śnicy']
# na kaprejach
# ['nakap rejach']
# na kozanowie
# ['nako zanowie']
# na l
# ['n al']
# na przeprośnej
# ['naprze prośnej']
# nc i
# ['n ci']
# ns i
# ['n si']
# olivera stone ’ a
# ['olivera stone’a']
# open na
# ['o penna']
# or the
# ['ort he']
# pani kostanecka
# ['paniko stanecka']
# pisac na
# ['pisa cna']
# pln z
# ['pl nz']
# polecenia ls
# ['poleceni als']
# ppe są
# ['p pesą']
# prezes ure
# ['prezesur e']
# przez george ’ a
# ['przez george’a']
# rd l
# ['r dl']
# roman c .
# ['roman c.']
# rue du
# ['r uedu']
# sa mają
# ['sama ją']
# sa michał
# ['sami chał']
# sa wyniosła
# ['sawy niosła']
# są dlań
# ['sąd lań']
# sie czesto
# ['siecze sto']
# ssa w
# ['ssaw', 's saw']
# ssl i
# ['ss li']
# s ytuacja
# ['sytuacja']
# talizman y
# ['talizmany']
# tryb ultra
# ['trybul tra']
# tsa i
# ['ts ai']
# tyś nie
# ['ty śnie']
# t ymczasem
# ['tymczasem', 'tym czasem']
# unfe z
# ['un fez']
# uokik i
# ['uo kiki']
# vcl i
# ['v cli']
# wiare w
# ['wiar ew']
# witamina c .
# ['witamina c.']
# w daborze
# ['wda borze']
# w ójt
# ['wójt', 'wój t']
# w rzekuciu
# ['wrze kuciu']
# zell am
# ['zel lam']
# zse w
# ['zs ew']
# zu nie
# ['z unie']
# z ae
# ['za e']
# z akład
# ['zakład', 'za kład', 'zakł ad']
# z ssp
# ['zs sp']
# żeś w
# ['że św']
# że c .
# ['że c.']
# że cba
# ['żec ba']
# alonso i
# ['alon soi']
# apple na
# ['ap plena']
# boboli w
# ['bob oliw', 'bobo liw']
# byc ale
# ['by cale']
# byla na
# ['by lana']
# chociaz na
# ['chocia zna']
# ciechu do
# ['cie chudo']
# ciechu na
# ['ciec huna']
# c. c .
# ['c. c.']
# di san
# ['disa n']
# do c .
# ['do c.']
# do pkw
# ['dop kw']
# eric alira
# ['erica lira']
# fap nie
# ['fa pnie']
# fudalego i
# ['fudale goi']
# gb w
# ['gbw', 'g bw']
# heh i
# ['he hi']
# ika i
# ['i kai']
# ike na
# ['i kena']
# i gliwic .
# ['igliwi c.']
# j od
# ['jod']
# j ózef
# ['józef']
# km intar
# ['kmin tar']
# ko ko
# ['koko', 'k oko', 'kok o']
# ko w
# ['k ow']
# ktora w
# ['kto raw']
# ktore z
# ['kto rez']
# k ierowca
# ['kierowca', 'kier owca']
# legis jest
# ['legi sjest']
# life nie
# ['li fenie']
# l m
# ['lm']
# l nzoz
# ['ln zoz']
# menis z
# ['me nisz']
# miał bym
# ['miałbym', 'miałby m']
# mna a
# ['mn aa']
# moze ona
# ['moz eona']
# mozna nie
# ['mo znanie']
# moż e
# ['może', 'mo że']
# m ożna
# ['można']
# nat king
# ['natk ing']
# na ktora
# ['n aktora']
# na zime
# ['nazi me']
# netia nie
# ['net ianie']
# nia i
# ['ni ai']
# niewiadomo czy
# ['niewiadom oczy']
# nie mowic
# ['niemo wic']
# n adal
# ['nadal', 'na dal', 'nad al']
# n ajwięcej
# ['najwięcej']
# obama ma
# ['oba mama']
# oi to
# ['o ito', 'oit o']
# pit bull
# ['pitbull']
# pkw nie
# ['pkwn ie']
# po slubie
# ['pos lubie']
# ptu i
# ['p tui']
# p rezes
# ['prezes', 'prez es']
# ra ra
# ['r ara']
# rohan nie
# ['ro hannie']
# roku l
# ['ro kul', 'rok ul']
# roku ś
# ['ro kuś', 'rok uś']
# rotcha w
# ['rot chaw']
# róbta co
# ['rób taco']
# równie ż
# ['również']
# sa wprowadził
# ['saw prowadził']
# sekretarz umig
# ['sekretarzu mig']
# s ię
# ['się']
# s zpital
# ['szpital']
# ten twoj
# ['tent woj']
# tfi z
# ['t fiz']
# to idz
# ['toi dz']
# t ą
# ['tą']
# t rzeba
# ['trzeba', 'trze ba', 'trzeb a']
# uke i
# ['u kei']
# v wkk
# ['vw kk']
# w cbś
# ['wc bś']
# w css
# ['wc ss']
# w domq
# ['wdom q']
# w drzewianowie
# ['wdrzew ianowie']
# w mycielewie
# ['wmyci elewie', 'wmycie lewie']
# w nuk
# ['wnuk']
# w piłke
# ['wpił ke']
# w swem
# ['wsw em']
# w tpsa
# ['wt psa']
# zdaniem ao
# ['zdanie mao']
# znajduja sie
# ['znajduj asie']
# znow sie
# ['zn owsie']
# z abu
# ['za bu']
# z amiast
# ['zamiast', 'za miast', 'zamia st']
# z eb
# ['ze b']
# z oczów
# ['zocz ów']
# z ultra
# ['zul tra']
# aaa nie
# ['aa anie']
# adam c .
# ['adam c.']
# awaru nie
# ['awar unie']
# bene nie
# ['be nenie']
# biziela w
# ['bizie law']
# by ktos
# ['byk tos']
# b ełchatowska
# ['bełchatowska']
# casa de
# ['ca sade']
# centyla w
# ['cen tylaw', 'centy law']
# czegośmy się
# ['czegoś mysię']
# c d
# ['cd']
# c zęsto
# ['często']
# dei w
# ['de iw']
# di natale
# ['dina tale']
# do cba
# ['doc ba']
# do granic .
# ['dograni c.']
# do mysłowic .
# ['domysłowi c.']
# do nasadzeń
# ['dona sadzeń']
# eksportu sa
# ['eksport usa']
# eures w
# ['eure sw']
# fair use
# ['fai ruse']
# fed z
# ['fe dz']
# gdybym żył
# ['gdyby mżył']
# gdzieśmy się
# ['gdzieś mysię']
# gmo na
# ['g mona', 'gm ona']
# got the
# ['gott he']
# had a
# ['ha da']
# henr yka
# ['henryka', 'henry ka', 'henryk a']
# hills and
# ['hill sand']
# igła c
# ['ig łac']
# il est
# ['ile st']
# inn w
# ['in nw']
# ipo w
# ['i pow', 'ip ow']
# i george ’ a
# ['i george’a']
# i nela
# ['in ela']
# i ns
# ['in s']
# i osir
# ['ios ir']
# i spac
# ['is pac']
# i wks
# ['iw ks']
# jak bylem
# ['jakby lem']
# janus z
# ['janusz']
# ja potrafie
# ['japo trafie']
# kgp w
# ['kg pw']
# klubu ju
# ['klub uju']
# kocurekola nie
# ['kocurek olanie']
# ko i
# ['koi']
# krause z
# ['kraus ez']
# k ilkunastu
# ['kilkunastu', 'kilku nastu']
# k oniec
# ['koniec']
# k rystyna
# ['krystyna', 'krys tyna', 'krysty na', 'krystyn a']
# legis ustawy
# ['legi sustawy']
# lenk i
# ['lenki', 'len ki']
# life na
# ['li fena']
# l ider
# ['lider', 'li der', 'lid er']
# l iwona
# ['liw ona']
# l ruch
# ['lr uch']
# ło no
# ['łono', 'łon o']
# media sa
# ['me diasa']
# menis w
# ['meni sw']
# mna i
# ['mn ai']
# modyfi kowanych
# ['modyfikowanych']
# moglo by
# ['mo globy']
# music i
# ['musi ci']
# m łodzież
# ['młodzież']
# nadaja sie
# ['nada jasie', 'nadaj asie']
# na glowe
# ['nagl owe']
# na głowe
# ['nagło we']
# na slasku
# ['nas lasku']
# nie moj
# ['niem oj']
# nie myśle
# ['niemy śle']
# nie powinnas
# ['niepowinna s']
# nie robia
# ['nierobi a']
# n asza
# ['nasza', 'na sza', 'nas za', 'nasz a']
# n iewiele
# ['niewiele', 'nie wiele']
# n igdy
# ['nigdy', 'ni gdy']
# obym nie
# ['oby mnie']
# opoczno sa
# ['opoczn osa']
# orange w
# ['orang ew']
# osob na
# ['osobna']
# o nrach
# ['on rach', 'onr ach']
# o statni
# ['ostatni']
# palace w
# ['pala cew']
# pare osob
# ['pareo sob']
# pater noster
# ['paternoster']
# przeciez on
# ['przecie zon']
# roku cu
# ['ro kucu']
# r odzice
# ['rodzice', 'ro dzice', 'rodzi ce', 'rodzic e']
# sada z
# ['sad az']
# sa bez
# ['sab ez']
# sa dwie
# ['sad wie']
# sa jacek
# ['saja cek']
# sa pod
# ['sap od', 'sapo d']
# sa wprowadza
# ['saw prowadza']
# siedziec na
# ['siedzie cna']
# soba a
# ['sob aa']
# strategies for
# ['strategie sfor']
# s iatkarki
# ['siatkarki', 'siat karki']
# tfi to
# ['t fito']
# tomasz imiński
# ['tomas zimiński']
# troche o
# ['t rocheo']
# uczyc ale
# ['uczy cale']
# upon a
# ['up ona']
# walczyc o
# ['walczy co']
# wioś w
# ['wio św']
# wolał bym
# ['wolałbym', 'w olałbym', 'wolałby m']
# w app
# ['wa pp', 'wap p']
# w cba
# ['wc ba']
# w czorajszy
# ['wczorajszy']
# w io
# ['wio']
# w ping
# ['wp ing']
# w rocławianie
# ['wrocławianie', 'wrocław ianie', 'wrocławi anie', 'wrocławia nie', 'wrocławian ie']
# w zsm
# ['wz sm']
# zeby cie
# ['ze bycie']
# zkp w
# ['zk pw']
# zrobic na
# ['zrobi cna']
# zsb w
# ['zs bw']
# zsm w
# ['zs mw']
# z andre
# ['zandr e']
# z kc .
# ['zk c.']
# z kww
# ['zk ww']
# z osir
# ['zosi r']
# z ulks
# ['zul ks']
# abym o
# ['aby mo']
# ale moj
# ['alem oj']
# ale niewiem
# ['alenie wiem']
# amd nie
# ['am dnie']
# arkadiusz c .
# ['arkadiusz c.']
# a gnieszka
# ['agnieszka']
# a ktos
# ['ak tos', 'akt os']
# a sada
# ['as ada', 'asa da']
# bazylko i
# ['bazyl koi']
# bo jezeli
# ['boje zeli']
# bylo sie
# ['by losie']
# byłąm w
# ['byłą mw']
# był bym
# ['byłbym', 'byłby m']
# cen oc .
# ['ceno c.']
# ciechu nie
# ['ciec hunie']
# cosmo wie
# ['cos mowie']
# cośmy tu
# ['coś mytu']
# coz za
# ['co zza']
# c .
# ['c.']
# c entrum
# ['centrum', 'cent rum', 'centr um', 'centru m']
# dalo sie
# ['da losie', 'dal osie']
# da graso
# ['dag raso']
# deras a
# ['de rasa', 'der asa']
# die toten
# ['dieto ten']
# drm i
# ['dr mi']
# dzierżka de
# ['dzierż kade']
# ekstraklasa sa
# ['ekstraklas asa']
# focusa i
# ['focus ai']
# gawronika i
# ['gawroni kai']
# heh ale
# ['he hale']
# h enryk
# ['henryk', 'hen ryk', 'henry k']
# h istoria
# ['historia']
# idi amin
# ['i diamin']
# id est
# ['ide st']
# iedy w
# ['ie dyw']
# inteligo i
# ['inteli goi']
# i bks
# ['ib ks']
# i mmks
# ['im mks']
# i zle
# ['iz le']
# jade z
# ['jad ez']
# jakbym ich
# ['jakby mich']
# jan c .
# ['jan c.']
# ja mówie
# ['jamów ie']
# kennedy ’ ego i
# ['kennedy’e goi', 'kennedy’ego i']
# kpwig na
# ['kp wigna']
# ktora by
# ['kto raby']
# kw psp
# ['kwp sp']
# luke i
# ['lu kei']
# l c
# ['lc']
# mc donald
# ['mcdonald']
# mc i
# ['m ci']
# megi nie
# ['m eginie', 'me ginie']
# miala na
# ['mi alana']
# miec z
# ['miecz']
# mi jakos
# ['mija kos']
# mms w
# ['m msw', 'mm sw']
# mogła bym
# ['mogłabym', 'mogłaby m']
# moj syn
# ['mojsy n']
# naprawdę bym
# ['napraw dębym']
# na dobe
# ['nadob e']
# na j
# ['n aj']
# ni mom
# ['nim om']
# no napewno
# ['nona pewno']
# n asze
# ['nasze', 'nas ze', 'nasz e']
# obyś nie
# ['oby śnie']
# ostrawie i
# ['ostra wiei']
# o jeja
# ['oje ja', 'ojej a']
# o rganizatorzy
# ['organizatorzy']
# o the
# ['ot he']
# pan c .
# ['pan c.']
# pan spyra
# ['pans pyra']
# piaf i
# ['pia fi']
# pinb w
# ['pin bw']
# pisal o
# ['pi salo', 'pis alo', 'pisa lo']
# poland na
# ['polan dna']
# poprostu jak
# ['poprostuj ak']
# po dwoch
# ['pod woch']
# po kazdym
# ['pokaz dym']
# po krótce
# ['pokrótce']
# priori i
# ['prior ii']
# ptc oraz
# ['pt coraz']
# ptu w
# ['p tuw', 'pt uw']
# p roces
# ['proces', 'pro ces', 'proc es', 'proce s']
# reb isze
# ['re bisze']
# redos nowy
# ['red osnowy', 'redo snowy']
# r ozpoczęła
# ['rozpoczęła']
# sada a
# ['sad aa']
# sampo i
# ['sam poi']
# sa ale
# ['saa le']
# sa podpisał
# ['sap odpisał']
# sa wprowadziła
# ['saw prowadziła']
# services w
# ['service sw']
# sie dzialo
# ['siedzi alo']
# sie napewno
# ['siena pewno']
# sokik w
# ['soki kw']
# sprawie c .
# ['sprawie c.']
# swoich owu
# ['swoi chowu']
# teddy da
# ['ted dyda']
# to narazie
# ['tona razie']
# to zrobie
# ['toz robie']
# troche boli
# ['troch eboli']
# typ y
# ['typy']
# union z
# ['unio nz']
# upc w
# ['u pcw']
# u rzędnicy
# ['urzędnicy']
# wants to
# ['want sto']

# %%
with open("Dane/1grams", "r") as ifile:
    for line in ifile:
        line_split = nltk.word_tokenize(line)
        line = " ".join(line_split[1:])
        fixed = fix_ngram(line, word_set)
        if fixed != [line]:
            print(line)
            print(fixed)
            result.append((line, fixed))

# %%
print(result)
# Out:
# []

# %%
import pickle
with open("ngramresult.pickle", "wb") as ofile:
    pickle.dump(result, ofile)
